# %%
import pandas as pd
import glob
import matplotlib.pyplot as plt

# All files ending with .txt
performances_file_list = glob.glob("./performances/*.csv")
predict_vs_real_file_list = glob.glob("./predict-vs-real/*.csv")
print(performances_file_list)
print(predict_vs_real_file_list)
# Out:
# ['./performances\\linha41_1mes(3)_2semanas(4)_performance.csv', './performances\\linha41_1mes(4)_2semanas(6)_performance.csv', './performances\\linha41_1mes(6)_2semanas(4)_performance.csv', './performances\\performance_1_meses.csv', './performances\\performance_2_meses.csv', './performances\\performance_3_meses.csv', './performances\\performance_4_meses.csv', './performances\\performance_5_meses.csv', './performances\\performance_6_meses.csv', './performances\\performance_7_meses.csv', './performances\\performance_total_linha41.csv']
# ['./predict-vs-real\\linha41_1mes(3)_2semanas(4)_predict.csv', './predict-vs-real\\linha41_1mes(4)_2semanas(6)_predict.csv', './predict-vs-real\\linha41_1mes(6)_2semanas(4)predict.csv', './predict-vs-real\\linha41_1mes(6)_2semanas(4)_predict.csv']

# %%
data = pd.read_csv('./predict-vs-real/linha41_1mes(6)_2semanas(4)predict.csv', delimiter=',')

# %%
data
# Out:
#      validations_per_hour  validations_per_hour_predicted
# 0                       0                            0.00
# 1                       0                            0.00
# 2                       0                            0.00
# 3                       0                            0.00
# 4                       0                            0.00
# ..                    ...                             ...
# 430                    80                          116.83
# 431                    48                          115.27
# 432                    45                           78.81
# 433                    43                           54.98
# 434                    29                           26.85
#
# [435 rows x 2 columns]

# %%
real_values = data.validations_per_hour
predictions = data.validations_per_hour_predicted

plt.figure(figsize=(10,10))
plt.scatter(real_values, predictions, c='crimson')

p1 = max(max(predictions), max(real_values.values))
p2 = min(min(predictions), min(real_values.values))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(30, 10))
plt.plot(range(len(real_values)), real_values, color='blue')
plt.plot(range(len(predictions)), predictions, color='red')
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.show()

# %%
data = pd.read_csv('./predict-vs-real/linha41_1mes(3)_2semanas(4)_predict.csv', delimiter=',')

real_values = data.validations_per_hour
predictions = data.validations_per_hour_predicted

plt.figure(figsize=(10,10))
plt.scatter(real_values, predictions, c='crimson')

p1 = max(max(predictions), max(real_values.values))
p2 = min(min(predictions), min(real_values.values))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(30, 10))
plt.plot(range(len(real_values)), real_values, color='blue')
plt.plot(range(len(predictions)), predictions, color='red')
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.show()
