# %%
import pandas as pd
import glob
import matplotlib.pyplot as plt

# All files ending with .txt
performances_file_list = glob.glob("./performances/*.csv")
predict_vs_real_file_list = glob.glob("./predict-vs-real/*.csv")
print(performances_file_list)
print(predict_vs_real_file_list)
# Out:
# ['./performances\\linha41_1mes(10)_2semanas(4)_performance.csv', './performances\\linha41_1mes(11)_2semanas(4)_performance.csv', './performances\\linha41_1mes(12)_2semanas(4)_performance.csv', './performances\\linha41_1mes(3)_2semanas(4)_performance.csv', './performances\\linha41_1mes(4)_2semanas(6)_performance.csv', './performances\\linha41_1mes(5)_2semanas(4)_performance.csv', './performances\\linha41_1mes(6)_2semanas(4)_performance.csv', './performances\\linha41_1mes(7)_2semanas(4)_performance.csv', './performances\\linha41_1mes(8)_2semanas(4)_performance.csv', './performances\\linha41_1mes(9)_2semanas(4)_performance.csv', './performances\\performance_1_meses.csv', './performances\\performance_2_meses.csv', './performances\\performance_3_meses.csv', './performances\\performance_4_meses.csv', './performances\\performance_5_meses.csv', './performances\\performance_6_meses.csv', './performances\\performance_7_meses.csv', './performances\\performance_total_linha41.csv', './performances\\ranking_top100.csv']
# ['./predict-vs-real\\linha41_1mes(10)_2semanas(4)_predict.csv', './predict-vs-real\\linha41_1mes(11)_2semanas(4)_predict.csv', './predict-vs-real\\linha41_1mes(12)_2semanas(4)_predict.csv', './predict-vs-real\\linha41_1mes(3)_2semanas(4)_predict.csv', './predict-vs-real\\linha41_1mes(4)_2semanas(6)_predict.csv', './predict-vs-real\\linha41_1mes(5)_2semanas(4)_predict.csv', './predict-vs-real\\linha41_1mes(6)_2semanas(4)_predict.csv', './predict-vs-real\\linha41_1mes(7)_2semanas(4)_predict.csv', './predict-vs-real\\linha41_1mes(8)_2semanas(4)_predict.csv', './predict-vs-real\\linha41_1mes(9)_2semanas(4)_predict.csv']

# %%
data = pd.read_csv('./predict-vs-real/linha41_1mes(5)_2semanas(4)_predict.csv', delimiter=',')

# %%
data
# Out:
#      validations_per_hour  validations_per_hour_predicted
# 0                       0                           0.140
# 1                       0                           0.140
# 2                       0                           0.140
# 3                       0                           0.140
# 4                       0                           0.140
# ..                    ...                             ...
# 430                    80                         106.740
# 431                    48                          61.460
# 432                    45                          62.380
# 433                    43                          61.770
# 434                    29                          20.207
#
# [435 rows x 2 columns]

# %%
for i in range(3, 11):
    data = pd.read_csv(f'./predict-vs-real/linha41_1mes({i})_2semanas(4)_predict.csv', delimiter=',')
    real_values = data.validations_per_hour
    predictions = data.validations_per_hour_predicted
    p1 = max(max(predictions), max(real_values.values))
    p2 = min(min(predictions), min(real_values.values))
    fig, axs = plt.subplots(2,2)
    plt.figure(figsize=(10,10))
    plt.scatter(real_values, predictions, c='crimson')
    plt.plot([p1, p2], [p1, p2], 'b-')
    plt.xlabel('True Values', fontsize=15)
    plt.ylabel('Predictions', fontsize=15)
    plt.axis('equal')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-e7f928ab8a44> in <module>
#       1 for i in range(3, 11):
# ----> 2     data = pd.read_csv(f'./predict-vs-real/linha41_1mes({i})_2semanas(4)_predict.csv', delimiter=',')
#       3     real_values = data.validations_per_hour
#       4     predictions = data.validations_per_hour_predicted
#       5     p1 = max(max(predictions), max(real_values.values))
#
# ~\anaconda3\envs\ml\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~\anaconda3\envs\ml\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# ~\anaconda3\envs\ml\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# ~\anaconda3\envs\ml\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# ~\anaconda3\envs\ml\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# ~\anaconda3\envs\ml\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# ~\anaconda3\envs\ml\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: './predict-vs-real/linha41_1mes(3)_2semanas(4)_predict.csv'

# %%
real_values = data.validations_per_hour
predictions = data.validations_per_hour_predicted

plt.figure(figsize=(10,10))
plt.scatter(real_values, predictions, c='crimson')

p1 = max(max(predictions), max(real_values.values))
p2 = min(min(predictions), min(real_values.values))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(30, 10))
plt.plot(range(len(real_values)), real_values, color='blue')
plt.plot(range(len(predictions)), predictions, color='red')
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.show()

# %%
data = pd.read_csv('./predict-vs-real/linha41_1mes(5)_2semanas(4)_predict.csv', delimiter=',')

real_values = data.validations_per_hour
predictions = data.validations_per_hour_predicted

plt.figure(figsize=(10,10))
plt.scatter(real_values, predictions, c='crimson')

p1 = max(max(predictions), max(real_values.values))
p2 = min(min(predictions), min(real_values.values))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(30, 10))
plt.plot(range(len(real_values)), real_values, color='blue')
plt.plot(range(len(predictions)), predictions, color='red')
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.show()
