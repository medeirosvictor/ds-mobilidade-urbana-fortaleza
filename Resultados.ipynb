# %%
import pandas as pd
import glob
import matplotlib.pyplot as plt

# All files ending with .txt
performances_file_list = glob.glob("./performances/2018/*.csv")
predict_vs_real_file_list = glob.glob("./predict-vs-real/2018/*.csv")
print(performances_file_list)
print(predict_vs_real_file_list)
# Out:
# ['./performances/2018\\linha325_1mes(6)_2semanas(4)_performance.csv', './performances/2018\\linha41_1mes(3)_1semanas(4)_performance.csv', './performances/2018\\linha41_1mes(4)_2semanas(6)_performance.csv', './performances/2018\\linha41_1mes(6)_2semanas(4)_performance.csv', './performances/2018\\performance_total_linha325.csv', './performances/2018\\performance_total_linha41.csv', './performances/2018\\ranking_top100_2018.csv']
# ['./predict-vs-real/2018\\linha325_1mes(6)_2semanas(4)_predict.csv', './predict-vs-real/2018\\linha41_1mes(3)_1semanas(4)_predict.csv', './predict-vs-real/2018\\linha41_1mes(4)_2semanas(6)_predict.csv', './predict-vs-real/2018\\linha41_1mes(6)_2semanas(4)_predict.csv']

# %%
# data1 = pd.read_csv('./predict-vs-real/linha41_1mes(3)_2semanas(4)_predict.csv', delimiter=',')
# data2 = pd.read_csv('./predict-vs-real/linha325_1mes(3)_2semanas(4)_predict.csv', delimiter=',')

# %%
# for i in range(3, 13):
#     data = pd.read_csv(f'./predict-vs-real/linha41_1mes({i})_2semanas(4)_predict.csv', delimiter=',')
#     real_values = data.validations_per_hour
#     predictions = data.validations_per_hour_predicted
#     p1 = max(max(predictions), max(real_values.values))
#     p2 = min(min(predictions), min(real_values.values))
#     plt.figure(figsize=(10,10))
#     plt.scatter(real_values, predictions, c='crimson')
#     plt.plot([p1, p2], [p1, p2], 'b-')
#     plt.xlabel('True Values', fontsize=15)
#     plt.ylabel('Predictions', fontsize=15)
#     plt.title(f'MES {i} PREVENDO MES 4')
#     plt.axis('equal')
#     plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-bc7f6c51abd9> in <module>
#       1 for i in range(3, 13):
# ----> 2     data = pd.read_csv(f'./predict-vs-real/linha41_1mes({i})_2semanas(4)_predict.csv', delimiter=',')
#       3     real_values = data.validations_per_hour
#       4     predictions = data.validations_per_hour_predicted
#       5     p1 = max(max(predictions), max(real_values.values))
#
# ...

# %%
data = pd.read_csv('./predict-vs-real/2020/linha41_1mes(3)_1semanas(4)_predict.csv', delimiter=',')


real_values = data.validations_per_hour
predictions = data.validations_per_hour_predicted

plt.figure(figsize=(10,10))
plt.scatter(real_values, predictions, c='crimson')

p1 = max(max(predictions), max(real_values.values))
p2 = min(min(predictions), min(real_values.values))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.show()

data = pd.read_csv('./predict-vs-real/2018/linha41_1mes(3)_1semanas(4)_predict.csv', delimiter=',')

real_values = data.validations_per_hour
predictions = data.validations_per_hour_predicted

plt.figure(figsize=(10,10))
plt.scatter(real_values, predictions, c='crimson')

p1 = max(max(predictions), max(real_values.values))
p2 = min(min(predictions), min(real_values.values))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.show()

data = pd.read_csv('./predict-vs-real/2015/linha41_1mes(3)_1semanas(4)_predict.csv', delimiter=',')

# data
real_values = data.validations_per_hour
predictions = data.validations_per_hour_predicted


plt.figure(figsize=(10,10))
plt.scatter(real_values, predictions, c='crimson')

p1 = max(max(predictions), max(real_values.values))
p2 = min(min(predictions), min(real_values.values))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(30, 10))
plt.plot(range(len(real_values)), real_values, color='blue')
plt.plot(range(len(predictions)), predictions, color='red')
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.show()

# %%
data = pd.read_csv('./predict-vs-real/linha41_1mes(5)_2semanas(4)_predict.csv', delimiter=',')

real_values = data.validations_per_hour
predictions = data.validations_per_hour_predicted

plt.figure(figsize=(10,10))
plt.scatter(real_values, predictions, c='crimson')

p1 = max(max(predictions), max(real_values.values))
p2 = min(min(predictions), min(real_values.values))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(30, 10))
plt.plot(range(len(real_values)), real_values, color='blue')
plt.plot(range(len(predictions)), predictions, color='red')
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.show()
